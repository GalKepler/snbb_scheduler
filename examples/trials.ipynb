# %%
from snbb_scheduler.config import SchedulerConfig
from snbb_scheduler.sessions import discover_sessions
from snbb_scheduler.manifest import build_manifest

# %%
cfg = SchedulerConfig.from_yaml(
    "/home/galkepler/Projects/snbb_scheduler/examples/snbb_config.yaml"
)
sessions = discover_sessions(cfg)
manifest = build_manifest(sessions, cfg)

print(manifest.groupby("procedure").size())
# Out:
# procedure
# bids    2
# dtype: int64

# %%
import pandas as pd

pd.read_csv("/media/storage/yalab-dev/snbb_scheduler/bids/.heudiconv/CLMC10/ses-202407110849/info/dicominfo_ses-202407110849.tsv", sep="\t")
# Out:
#     total_files_till_now                                   example_dcm_file  \
# 0                     18      07110849_localizer_3D_2 (9X5X5)_1-Copy(1).dcm
# 1                     24         07110849_SpinEchoFieldMap_AP_1-Copy(1).dcm
# 2                     30         07110849_SpinEchoFieldMap_PA_1-Copy(1).dcm
# 3                     32             07110849_rsfMRI_AP_SBRef_1-Copy(1).dcm
# 4                   1632                   07110849_rsfMRI_AP_1-Copy(1).dcm
# 5                   1736  07110849_t2_tirm_tra_dark-fluid_FLAIR_1-Copy(1...
# 6                   2088               07110849_T1w_MPRAGE_RL_1-Copy(1).dcm
# 7                   2440               07110849_T1w_MPRAGE_RL_1-Copy(1).dcm
# 8                   2792                  07110849_T2w_SPC_RL_1-Copy(1).dcm
# 9                   2798        07110849_SE_tfMRI_FieldMap_AP_1-Copy(1).dcm
# 10                  2804        07110849_SE_tfMRI_FieldMap_PA_1-Copy(1).dcm
# 11                  2806         07110849_tfMRI_BJJ1_AP_SBRef_1-Copy(1).dcm
# 12                  3228               07110849_tfMRI_BJJ1_AP_1-Copy(1).dcm
# 13                  3230    07110849_tfMRI_Climbing1_AP_SBRef_1-Copy(1).dcm
# 14                  3652          07110849_tfMRI_Climbing1_AP_1-Copy(1).dcm
# 15                  3654       07110849_tfMRI_Music1_AP_SBRef_1-Copy(1).dcm
# 16                  4076             07110849_tfMRI_Music1_AP_1-Copy(1).dcm
# 17                  4078  07110849_dMRI_MB4_185dirs_d15D45_AP_SBRef_1-Co...
# 18                  4450  07110849_dMRI_MB4_185dirs_d15D45_AP_1-Copy(1).dcm
# 19                  4452  07110849_dMRI_MB4_6dirs_d15D45_PA_SBRef_1-Copy...
# 20                  4466    07110849_dMRI_MB4_6dirs_d15D45_PA_1-Copy(1).dcm
# 21                  4468  07110849_tfMRI_EmotionalNBack_AP_SBRef_1-Copy(...
# 22                  5172     07110849_tfMRI_EmotionalNBack_AP_1-Copy(1).dcm
#
#                          series_id                         dcm_dir_name  \
# 0         1-localizer_3D_2 (9X5X5)             1_localizer_3D_2 (9X5X5)
# 1            2-SpinEchoFieldMap_AP                2_SpinEchoFieldMap_AP
# 2            3-SpinEchoFieldMap_PA                3_SpinEchoFieldMap_PA
# 3                      4-rsfMRI_AP                    4_rsfMRI_AP_SBRef
# 4                      5-rsfMRI_AP                          5_rsfMRI_AP
# 5   6-t2_tirm_tra_dark-fluid_FLAIR       6_t2_tirm_tra_dark-fluid_FLAIR
# 6                  7-T1w_MPRAGE_RL                      7_T1w_MPRAGE_RL
# 7                  8-T1w_MPRAGE_RL                      8_T1w_MPRAGE_RL
# 8                     9-T2w_SPC_RL                         9_T2w_SPC_RL
# 9          10-SE_tfMRI_FieldMap_AP              10_SE_tfMRI_FieldMap_AP
# 10         11-SE_tfMRI_FieldMap_PA              11_SE_tfMRI_FieldMap_PA
# 11                12-tfMRI_BJJ1_AP               12_tfMRI_BJJ1_AP_SBRef
# 12                13-tfMRI_BJJ1_AP                     13_tfMRI_BJJ1_AP
# 13           14-tfMRI_Climbing1_AP          14_tfMRI_Climbing1_AP_SBRef
# 14           15-tfMRI_Climbing1_AP                15_tfMRI_Climbing1_AP
# 15              16-tfMRI_Music1_AP             16_tfMRI_Music1_AP_SBRef
# 16              17-tfMRI_Music1_AP                   17_tfMRI_Music1_AP
# 17   18-dMRI_MB4_185dirs_d15D45_AP  18_dMRI_MB4_185dirs_d15D45_AP_SBRef
# 18   19-dMRI_MB4_185dirs_d15D45_AP        19_dMRI_MB4_185dirs_d15D45_AP
# 19     20-dMRI_MB4_6dirs_d15D45_PA    20_dMRI_MB4_6dirs_d15D45_PA_SBRef
# 20     21-dMRI_MB4_6dirs_d15D45_PA          21_dMRI_MB4_6dirs_d15D45_PA
# 21      22-tfMRI_EmotionalNBack_AP     22_tfMRI_EmotionalNBack_AP_SBRef
# 22      23-tfMRI_EmotionalNBack_AP           23_tfMRI_EmotionalNBack_AP
#
#     series_files  unspecified  dim1  dim2  dim3  dim4  ...  \
# 0             18          NaN   384   384    18     1  ...
# 1              6          NaN   112    86    72     6  ...
# 2              6          NaN   112    86    72     6  ...
# 3              2          NaN   112    86    72     2  ...
# 4           1600          NaN   112    86    72  1600  ...
# 5            104          NaN   320   240   104     1  ...
# 6            352          NaN   256   192   352     1  ...
# 7            352          NaN   256   192   352     1  ...
# 8            352          NaN   256   192   352     1  ...
# 9              6          NaN   102   102    72     6  ...
# 10             6          NaN   102   102    72     6  ...
# 11             2          NaN   102   102    72     2  ...
# 12           422          NaN   102   102    72   422  ...
# 13             2          NaN   102   102    72     2  ...
# 14           422          NaN   102   102    72   422  ...
# 15             2          NaN   102   102    72     2  ...
# 16           422          NaN   102   102    72   422  ...
# 17             2          NaN   128   128    88     2  ...
# 18           372          NaN   128   128    88   372  ...
# 19             2          NaN   128   128    88     2  ...
# 20            14          NaN   128   128    88    14  ...
# 21             2          NaN   112    86    72     2  ...
# 22           704          NaN   112    86    72   704  ...
#
#                   series_description  sequence_name  \
# 0             localizer_3D_2 (9X5X5)         *fl2d1
# 1                SpinEchoFieldMap_AP    epse2d1_112
# 2                SpinEchoFieldMap_PA    epse2d1_112
# 3                    rsfMRI_AP_SBRef   epfid2d1_112
# 4                          rsfMRI_AP   epfid2d1_112
# 5       t2_tirm_tra_dark-fluid_FLAIR     *tir2d1_16
# 6                      T1w_MPRAGE_RL     *tfl3d1_16
# 7                      T1w_MPRAGE_RL     *tfl3d1_16
# 8                         T2w_SPC_RL       *spc_380
# 9               SE_tfMRI_FieldMap_AP    epse2d1_102
# 10              SE_tfMRI_FieldMap_PA    epse2d1_102
# 11               tfMRI_BJJ1_AP_SBRef   epfid2d1_102
# 12                     tfMRI_BJJ1_AP   epfid2d1_102
# 13          tfMRI_Climbing1_AP_SBRef   epfid2d1_102
# 14                tfMRI_Climbing1_AP   epfid2d1_102
# 15             tfMRI_Music1_AP_SBRef   epfid2d1_102
# 16                   tfMRI_Music1_AP   epfid2d1_102
# 17  dMRI_MB4_185dirs_d15D45_AP_SBRef    epse2d1_128
# 18        dMRI_MB4_185dirs_d15D45_AP        ep_b5#1
# 19    dMRI_MB4_6dirs_d15D45_PA_SBRef    epse2d1_128
# 20          dMRI_MB4_6dirs_d15D45_PA        ep_b5#1
# 21     tfMRI_EmotionalNBack_AP_SBRef   epfid2d1_112
# 22           tfMRI_EmotionalNBack_AP   epfid2d1_112
#
#                                            image_type  accession_number  \
# 0       ('ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D')               NaN
# 1        ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 2        ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 3        ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 4   ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'MOSA...               NaN
# 5       ('ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D')               NaN
# 6               ('ORIGINAL', 'PRIMARY', 'M', 'DIS2D')               NaN
# 7       ('ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS2D')               NaN
# 8      ('ORIGINAL', 'PRIMARY', 'M', 'DIS3D', 'DIS2D')               NaN
# 9        ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 10       ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 11       ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 12  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'MOSA...               NaN
# 13       ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 14  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'MOSA...               NaN
# 15       ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 16  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'MOSA...               NaN
# 17       ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 18  ('ORIGINAL', 'PRIMARY', 'DIFFUSION', 'NONE', '...               NaN
# 19       ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 20  ('ORIGINAL', 'PRIMARY', 'DIFFUSION', 'NONE', '...               NaN
# 21       ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'MOSAIC')               NaN
# 22  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'MOSA...               NaN
#
#     patient_age  patient_sex      date  \
# 0           NaN          NaN  20240711
# 1           NaN          NaN  20240711
# 2           NaN          NaN  20240711
# 3           NaN          NaN  20240711
# 4           NaN          NaN  20240711
# 5           NaN          NaN  20240711
# 6           NaN          NaN  20240711
# 7           NaN          NaN  20240711
# 8           NaN          NaN  20240711
# 9           NaN          NaN  20240711
# 10          NaN          NaN  20240711
# 11          NaN          NaN  20240711
# 12          NaN          NaN  20240711
# 13          NaN          NaN  20240711
# 14          NaN          NaN  20240711
# 15          NaN          NaN  20240711
# 16          NaN          NaN  20240711
# 17          NaN          NaN  20240711
# 18          NaN          NaN  20240711
# 19          NaN          NaN  20240711
# 20          NaN          NaN  20240711
# 21          NaN          NaN  20240711
# 22          NaN          NaN  20240711
#
#                                            series_uid        time custom
# 0   1.3.12.2.1107.5.2.43.66024.2024071108593835313...  85939.6950    NaN
# 1   1.3.12.2.1107.5.2.43.66024.2024071109042046595...  90432.4650    NaN
# 2   1.3.12.2.1107.5.2.43.66024.2024071109045650226...  90508.9350    NaN
# 3   1.3.12.2.1107.5.2.43.66024.2024071109061136422...  90611.3350    NaN
# 4   1.3.12.2.1107.5.2.43.66024.2024071109061211629...  90621.0850    NaN
# 5   1.3.12.2.1107.5.2.43.66024.2024071109191639716...  91830.2700    NaN
# 6   1.3.12.2.1107.5.2.43.66024.2024071109250839145...  92038.3675    NaN
# 7   1.3.12.2.1107.5.2.43.66024.2024071109203714504...  92038.3675    NaN
# 8   1.3.12.2.1107.5.2.43.66024.2024071109301587327...  92516.4275    NaN
# 9   1.3.12.2.1107.5.2.43.66024.2024071109311738767...  93127.5400    NaN
# 10  1.3.12.2.1107.5.2.43.66024.2024071109314662409...  93156.7500    NaN
# 11  1.3.12.2.1107.5.2.43.66024.2024071109330245247...  93302.3675    NaN
# 12  1.3.12.2.1107.5.2.43.66024.2024071109330245425...  93312.1175    NaN
# 13  1.3.12.2.1107.5.2.43.66024.2024071109362641793...  93626.3250    NaN
# 14  1.3.12.2.1107.5.2.43.66024.2024071109362641971...  93636.0750    NaN
# 15  1.3.12.2.1107.5.2.43.66024.2024071109393242521...  93931.6650    NaN
# 16  1.3.12.2.1107.5.2.43.66024.2024071109393244317...  93941.4150    NaN
# 17  1.3.12.2.1107.5.2.43.66024.2024071109440556104...  94413.2450    NaN
# 18  1.3.12.2.1107.5.2.43.66024.2024071109440551879...  94430.7450    NaN
# 19  1.3.12.2.1107.5.2.43.66024.2024071109552491650...  95526.1625    NaN
# 20  1.3.12.2.1107.5.2.43.66024.2024071109552488116...  95543.6625    NaN
# 21  1.3.12.2.1107.5.2.43.66024.2024071109570585107...  95704.5525    NaN
# 22  1.3.12.2.1107.5.2.43.66024.2024071109570585276...  95714.3025    NaN
#
# [23 rows x 28 columns]

# %%
import pandas as pd
d = pd.read_csv("~/Downloads/linked_sessions.csv")
d = d[d["dicom_path"].notna()]
d = d[d["subject_code"] == "CLMC10"]
d.to_csv("/home/galkepler/Projects/snbb_scheduler/examples/linked_sessions.csv", index=False)
# d = pd.read_parquet("/media/storage/yalab-dev/snbb_scheduler/.scheduler_state.parquet")
# d.loc[:0].to_parquet("/media/storage/yalab-dev/snbb_scheduler/.scheduler_state.parquet")
